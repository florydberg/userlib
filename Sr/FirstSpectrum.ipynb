# %%
from spectrumdevice import SpectrumDigitiserCard, SpectrumAWGCard

# digitiser_1 = SpectrumDigitiserCard(device_number=0)
awg_1 = SpectrumAWGCard(device_number=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from spectrumdevice import SpectrumDigitiserCard, SpectrumAWGCard
#       3 # digitiser_1 = SpectrumDigitiserCard(device_number=0)
#       4 awg_1 = SpectrumAWGCard(device_number=1)
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\__init__.py:65
#      60 # Christian Baker, King's College London
#      61 # Copyright (c) 2021 School of Biomedical Engineering & Imaging Sciences, King's College London
#      62 # Licensed under the MIT. You may obtain a copy at https://opensource.org/licenses/MIT.
#      64 from .measurement import Measurement
# ---> 65 from .devices.digitiser.digitiser_card import SpectrumDigitiserCard
#      66 from .devices.digitiser.digitiser_channel import SpectrumDigitiserAnalogChannel, SpectrumDigitiserIOLine
#      67 from .devices.digitiser.digitiser_star_hub import SpectrumDigitiserStarHub
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\digitiser\__init__.py:7
#       1 """ Provides classes for controlling Spectrum digitiser cards and hubs."""
#       3 # Christian Baker, King's College London
#       4 # Copyright (c) 2021 School of Biomedical Engineering & Imaging Sciences, King's College London
#       5 # Licensed under the MIT. You may obtain a copy at https://opensource.org/licenses/MIT.
# ----> 7 from spectrumdevice.devices.digitiser.digitiser_card import SpectrumDigitiserCard
#       8 from spectrumdevice.devices.digitiser.digitiser_channel import SpectrumDigitiserAnalogChannel
#       9 from spectrumdevice.devices.digitiser.digitiser_interface import (
#      10     SpectrumDigitiserAnalogChannelInterface,
#      11     SpectrumDigitiserInterface,
#      12 )
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\digitiser\digitiser_card.py:29
#      11 from numpy.typing import NDArray
#      13 from spectrum_gmbh.py_header.regs import (
#      14     M2CMD_CARD_WAITREADY,
#      15     SPC_AVERAGES,
#    (...)
#      27     TYP_M2PEXPSERIES,
#      28 )
# ---> 29 from spectrumdevice.devices.abstract_device import AbstractSpectrumCard
#      30 from spectrumdevice.devices.digitiser.abstract_spectrum_digitiser import AbstractSpectrumDigitiser
#      31 from spectrumdevice.devices.digitiser.digitiser_interface import (
#      32     SpectrumDigitiserAnalogChannelInterface,
#      33     SpectrumDigitiserIOLineInterface,
#      34 )
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\abstract_device\__init__.py:7
#       1 """" Defines interfaces and partially implemented abstract classes containing code common to all Spectrum devices"""
#       3 # Christian Baker, King's College London
#       4 # Copyright (c) 2021 School of Biomedical Engineering & Imaging Sciences, King's College London
#       5 # Licensed under the MIT. You may obtain a copy at https://opensource.org/licenses/MIT.
# ----> 7 from spectrumdevice.devices.abstract_device.abstract_spectrum_card import AbstractSpectrumCard
#       8 from spectrumdevice.devices.abstract_device.abstract_spectrum_channel import AbstractSpectrumChannel
#       9 from spectrumdevice.devices.abstract_device.abstract_spectrum_device import AbstractSpectrumDevice
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\abstract_device\abstract_spectrum_card.py:37
#      12 from typing import Any, List, Optional, Sequence, Tuple
#      14 from spectrum_gmbh.py_header.regs import (
#      15     M2CMD_DATA_STARTDMA,
#      16     M2CMD_DATA_STOPDMA,
#    (...)
#      35     SPC_MIINST_BYTESPERSAMPLE,
#      36 )
# ---> 37 from spectrumdevice.devices.abstract_device.abstract_spectrum_device import AbstractSpectrumDevice
#      38 from spectrumdevice.devices.abstract_device.device_interface import AnalogChannelInterfaceType, IOLineInterfaceType
#      39 from spectrumdevice.exceptions import (
#      40     SpectrumExternalTriggerNotEnabled,
#      41     SpectrumInvalidNumberOfEnabledChannels,
#      42     SpectrumNoTransferBufferDefined,
#      43     SpectrumTriggerOperationNotImplemented,
#      44 )
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\abstract_device\abstract_spectrum_device.py:10
#       7 from abc import ABC
#       8 from copy import copy
# ---> 10 from spectrumdevice.devices.abstract_device.device_interface import (
#      11     SpectrumDeviceInterface,
#      12     AnalogChannelInterfaceType,
#      13     IOLineInterfaceType,
#      14 )
#      15 from spectrumdevice.exceptions import SpectrumDeviceNotConnected, SpectrumDriversNotFound
#      16 from spectrumdevice.settings import SpectrumRegisterLength, TriggerSettings
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\abstract_device\device_interface.py:4
#       1 from abc import ABC, abstractmethod
#       2 from typing import List, Optional, Sequence, Tuple, TypeVar, Generic
# ----> 4 from spectrumdevice.devices.abstract_device.channel_interfaces import (
#       5     SpectrumAnalogChannelInterface,
#       6     SpectrumIOLineInterface,
#       7 )
#       8 from spectrumdevice.settings import (
#       9     AdvancedCardFeature,
#      10     AvailableIOModes,
#    (...)
#      19     TriggerSource,
#      20 )
#      21 from spectrumdevice.settings.card_dependent_properties import CardType
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\abstract_device\channel_interfaces.py:10
#       7 from abc import ABC, abstractmethod
#       8 from typing import TypeVar, Generic, Protocol
# ---> 10 from spectrumdevice.features.pulse_generator.interfaces import PulseGeneratorInterface
#      11 from spectrumdevice.settings import (
#      12     SpectrumRegisterLength,
#      13     IOLineMode,
#      14 )
#      15 from spectrumdevice.settings.channel import SpectrumAnalogChannelName, SpectrumChannelName
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\features\pulse_generator\interfaces.py:4
#       1 from abc import ABC, abstractmethod
#       2 from typing import Generic, TypeVar
# ----> 4 from spectrumdevice.settings import SpectrumRegisterLength
#       5 from spectrumdevice.settings.pulse_generator import (
#       6     PulseGeneratorMultiplexerTriggerSource,
#       7     PulseGeneratorOutputSettings,
#    (...)
#      10     PulseGeneratorTriggerSettings,
#      11 )
#      13 MultiplexerTriggerSourceTypeVar = TypeVar(
#      14     "MultiplexerTriggerSourceTypeVar", bound=PulseGeneratorMultiplexerTriggerSource
#      15 )
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\settings\__init__.py:16
#      13 from numpy.typing import NDArray
#      15 from spectrumdevice.settings.card_dependent_properties import ModelNumber
# ---> 16 from spectrumdevice.settings.card_features import CardFeature, AdvancedCardFeature
#      17 from spectrumdevice.settings.channel import (
#      18     InputImpedance,
#      19     InputCoupling,
#    (...)
#      22     OutputChannelStopLevelMode,
#      23 )
#      24 from spectrumdevice.settings.device_modes import AcquisitionMode, ClockMode, GenerationMode
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\settings\card_features.py:11
#       8 from enum import Enum
#       9 from typing import List
# ---> 11 from spectrumdevice.spectrum_wrapper import decode_bitmap_using_list_of_ints
#      12 from spectrum_gmbh.py_header.regs import (
#      13     SPCM_FEAT_MULTI,
#      14     SPCM_FEAT_GATE,
#    (...)
#      34     SPCM_FEAT_EXTFW_PULSEGEN,
#      35 )
#      37 # Devices return same value for SPCM_FEAT_STARHUB4, SPCM_FEAT_STARHUB4, SPCM_FEAT_STARHUB6_EXTM and
#      38 # SPCM_FEAT_STARHUB8_EXTM card features
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\spectrum_wrapper\__init__.py:11
#       8 from ctypes import c_void_p, byref, create_string_buffer
#       9 from typing import NewType, List
# ---> 11 from spectrumdevice.spectrum_wrapper.error_handler import error_handler
#      12 from spectrumdevice.exceptions import SpectrumIOError
#      14 logger = logging.getLogger(__name__)
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\spectrum_wrapper\error_handler.py:40
#      36                 errors[int(cells[2].strip())] = cells[3].strip()
#      37     return errors
# ---> 40 KNOWN_ERRORS_WITH_DESCRIPTIONS = _parse_errors_table()
#      41 ERROR_CODES_TO_IGNORE = [ERR_OK]
#      42 ERROR_CODES_TO_REPORT_BUT_NOT_RAISE = [ERR_LASTERR, ERR_TIMEOUT, ERR_ABORT]
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\spectrum_wrapper\error_handler.py:31, in _parse_errors_table()
#      29 def _parse_errors_table() -> Dict[int, str]:
#      30     errors: Dict[int, str] = {}
# ---> 31     errors_file = resources.files(__package__) / "spectrum_errors.csv"
#      32     with resources.as_file(errors_file) as file_path:
#      33         with open(file_path) as f:
#
# AttributeError: module 'importlib.resources' has no attribute 'files'

# %%
from spectrumdevice import MockSpectrumDigitiserCard, MockSpectrumDigitiserStarHub, MockSpectrumAWGCard
from spectrumdevice.settings import ModelNumber

mock_digitiser = MockSpectrumDigitiserCard(
    device_number=0,
    model=ModelNumber.TYP_M2P5966_X4,
    mock_source_frame_rate_hz=10.0,
    num_modules=2,
    num_channels_per_module=4
)
mock_hub = MockSpectrumDigitiserStarHub(device_number=0, child_cards=[mock_digitiser], master_card_index=0)
mock_awg = MockSpectrumAWGCard(
    device_number=0,
    model=ModelNumber.TYP_M2P6560_X4,
    num_modules=1,
    num_channels_per_module=1
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from spectrumdevice import MockSpectrumDigitiserCard, MockSpectrumDigitiserStarHub, MockSpectrumAWGCard
#       2 from spectrumdevice.settings import ModelNumber
#       4 mock_digitiser = MockSpectrumDigitiserCard(
#       5     device_number=0,
#       6     model=ModelNumber.TYP_M2P5966_X4,
#    (...)
#       9     num_channels_per_module=4
#      10 )
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\__init__.py:65
#      60 # Christian Baker, King's College London
#      61 # Copyright (c) 2021 School of Biomedical Engineering & Imaging Sciences, King's College London
#      62 # Licensed under the MIT. You may obtain a copy at https://opensource.org/licenses/MIT.
#      64 from .measurement import Measurement
# ---> 65 from .devices.digitiser.digitiser_card import SpectrumDigitiserCard
#      66 from .devices.digitiser.digitiser_channel import SpectrumDigitiserAnalogChannel, SpectrumDigitiserIOLine
#      67 from .devices.digitiser.digitiser_star_hub import SpectrumDigitiserStarHub
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\digitiser\__init__.py:7
#       1 """ Provides classes for controlling Spectrum digitiser cards and hubs."""
#       3 # Christian Baker, King's College London
#       4 # Copyright (c) 2021 School of Biomedical Engineering & Imaging Sciences, King's College London
#       5 # Licensed under the MIT. You may obtain a copy at https://opensource.org/licenses/MIT.
# ----> 7 from spectrumdevice.devices.digitiser.digitiser_card import SpectrumDigitiserCard
#       8 from spectrumdevice.devices.digitiser.digitiser_channel import SpectrumDigitiserAnalogChannel
#       9 from spectrumdevice.devices.digitiser.digitiser_interface import (
#      10     SpectrumDigitiserAnalogChannelInterface,
#      11     SpectrumDigitiserInterface,
#      12 )
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\digitiser\digitiser_card.py:29
#      11 from numpy.typing import NDArray
#      13 from spectrum_gmbh.py_header.regs import (
#      14     M2CMD_CARD_WAITREADY,
#      15     SPC_AVERAGES,
#    (...)
#      27     TYP_M2PEXPSERIES,
#      28 )
# ---> 29 from spectrumdevice.devices.abstract_device import AbstractSpectrumCard
#      30 from spectrumdevice.devices.digitiser.abstract_spectrum_digitiser import AbstractSpectrumDigitiser
#      31 from spectrumdevice.devices.digitiser.digitiser_interface import (
#      32     SpectrumDigitiserAnalogChannelInterface,
#      33     SpectrumDigitiserIOLineInterface,
#      34 )
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\abstract_device\__init__.py:7
#       1 """" Defines interfaces and partially implemented abstract classes containing code common to all Spectrum devices"""
#       3 # Christian Baker, King's College London
#       4 # Copyright (c) 2021 School of Biomedical Engineering & Imaging Sciences, King's College London
#       5 # Licensed under the MIT. You may obtain a copy at https://opensource.org/licenses/MIT.
# ----> 7 from spectrumdevice.devices.abstract_device.abstract_spectrum_card import AbstractSpectrumCard
#       8 from spectrumdevice.devices.abstract_device.abstract_spectrum_channel import AbstractSpectrumChannel
#       9 from spectrumdevice.devices.abstract_device.abstract_spectrum_device import AbstractSpectrumDevice
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\abstract_device\abstract_spectrum_card.py:37
#      12 from typing import Any, List, Optional, Sequence, Tuple
#      14 from spectrum_gmbh.py_header.regs import (
#      15     M2CMD_DATA_STARTDMA,
#      16     M2CMD_DATA_STOPDMA,
#    (...)
#      35     SPC_MIINST_BYTESPERSAMPLE,
#      36 )
# ---> 37 from spectrumdevice.devices.abstract_device.abstract_spectrum_device import AbstractSpectrumDevice
#      38 from spectrumdevice.devices.abstract_device.device_interface import AnalogChannelInterfaceType, IOLineInterfaceType
#      39 from spectrumdevice.exceptions import (
#      40     SpectrumExternalTriggerNotEnabled,
#      41     SpectrumInvalidNumberOfEnabledChannels,
#      42     SpectrumNoTransferBufferDefined,
#      43     SpectrumTriggerOperationNotImplemented,
#      44 )
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\abstract_device\abstract_spectrum_device.py:10
#       7 from abc import ABC
#       8 from copy import copy
# ---> 10 from spectrumdevice.devices.abstract_device.device_interface import (
#      11     SpectrumDeviceInterface,
#      12     AnalogChannelInterfaceType,
#      13     IOLineInterfaceType,
#      14 )
#      15 from spectrumdevice.exceptions import SpectrumDeviceNotConnected, SpectrumDriversNotFound
#      16 from spectrumdevice.settings import SpectrumRegisterLength, TriggerSettings
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\abstract_device\device_interface.py:4
#       1 from abc import ABC, abstractmethod
#       2 from typing import List, Optional, Sequence, Tuple, TypeVar, Generic
# ----> 4 from spectrumdevice.devices.abstract_device.channel_interfaces import (
#       5     SpectrumAnalogChannelInterface,
#       6     SpectrumIOLineInterface,
#       7 )
#       8 from spectrumdevice.settings import (
#       9     AdvancedCardFeature,
#      10     AvailableIOModes,
#    (...)
#      19     TriggerSource,
#      20 )
#      21 from spectrumdevice.settings.card_dependent_properties import CardType
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\devices\abstract_device\channel_interfaces.py:10
#       7 from abc import ABC, abstractmethod
#       8 from typing import TypeVar, Generic, Protocol
# ---> 10 from spectrumdevice.features.pulse_generator.interfaces import PulseGeneratorInterface
#      11 from spectrumdevice.settings import (
#      12     SpectrumRegisterLength,
#      13     IOLineMode,
#      14 )
#      15 from spectrumdevice.settings.channel import SpectrumAnalogChannelName, SpectrumChannelName
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\features\pulse_generator\interfaces.py:4
#       1 from abc import ABC, abstractmethod
#       2 from typing import Generic, TypeVar
# ----> 4 from spectrumdevice.settings import SpectrumRegisterLength
#       5 from spectrumdevice.settings.pulse_generator import (
#       6     PulseGeneratorMultiplexerTriggerSource,
#       7     PulseGeneratorOutputSettings,
#    (...)
#      10     PulseGeneratorTriggerSettings,
#      11 )
#      13 MultiplexerTriggerSourceTypeVar = TypeVar(
#      14     "MultiplexerTriggerSourceTypeVar", bound=PulseGeneratorMultiplexerTriggerSource
#      15 )
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\settings\__init__.py:16
#      13 from numpy.typing import NDArray
#      15 from spectrumdevice.settings.card_dependent_properties import ModelNumber
# ---> 16 from spectrumdevice.settings.card_features import CardFeature, AdvancedCardFeature
#      17 from spectrumdevice.settings.channel import (
#      18     InputImpedance,
#      19     InputCoupling,
#    (...)
#      22     OutputChannelStopLevelMode,
#      23 )
#      24 from spectrumdevice.settings.device_modes import AcquisitionMode, ClockMode, GenerationMode
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\settings\card_features.py:11
#       8 from enum import Enum
#       9 from typing import List
# ---> 11 from spectrumdevice.spectrum_wrapper import decode_bitmap_using_list_of_ints
#      12 from spectrum_gmbh.py_header.regs import (
#      13     SPCM_FEAT_MULTI,
#      14     SPCM_FEAT_GATE,
#    (...)
#      34     SPCM_FEAT_EXTFW_PULSEGEN,
#      35 )
#      37 # Devices return same value for SPCM_FEAT_STARHUB4, SPCM_FEAT_STARHUB4, SPCM_FEAT_STARHUB6_EXTM and
#      38 # SPCM_FEAT_STARHUB8_EXTM card features
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\spectrum_wrapper\__init__.py:11
#       8 from ctypes import c_void_p, byref, create_string_buffer
#       9 from typing import NewType, List
# ---> 11 from spectrumdevice.spectrum_wrapper.error_handler import error_handler
#      12 from spectrumdevice.exceptions import SpectrumIOError
#      14 logger = logging.getLogger(__name__)
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\spectrum_wrapper\error_handler.py:40
#      36                 errors[int(cells[2].strip())] = cells[3].strip()
#      37     return errors
# ---> 40 KNOWN_ERRORS_WITH_DESCRIPTIONS = _parse_errors_table()
#      41 ERROR_CODES_TO_IGNORE = [ERR_OK]
#      42 ERROR_CODES_TO_REPORT_BUT_NOT_RAISE = [ERR_LASTERR, ERR_TIMEOUT, ERR_ABORT]
#
# File c:\Users\florydberg01\anaconda3\envs\py38\lib\site-packages\spectrumdevice\spectrum_wrapper\error_handler.py:31, in _parse_errors_table()
#      29 def _parse_errors_table() -> Dict[int, str]:
#      30     errors: Dict[int, str] = {}
# ---> 31     errors_file = resources.files(__package__) / "spectrum_errors.csv"
#      32     with resources.as_file(errors_file) as file_path:
#      33         with open(file_path) as f:
#
# AttributeError: module 'importlib.resources' has no attribute 'files'
